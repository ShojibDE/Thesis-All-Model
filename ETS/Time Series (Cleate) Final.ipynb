# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv(r"E:\Hochschule Ansbach\Thesis\DATA\SCM_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Actual shipping days  Estimated shipping days  \
# 0           0                     3                        4
# 1           1                     5                        4
# 2           2                     4                        4
# 3           3                     3                        4
# 4           4                     2                        4
#
#     Delivery Status  Late_risk        Category Customer City Customer Segment  \
# 0  Advance shipping          0  Sporting Goods        Caguas         Consumer
# 1     Late delivery          1  Sporting Goods        Caguas         Consumer
# 2  Shipping on time          0  Sporting Goods      San Jose         Consumer
# 3  Advance shipping          0  Sporting Goods   Los Angeles      Home Office
# 4  Advance shipping          0  Sporting Goods        Caguas        Corporate
#
#   Department      Orders Date  Order Item Product Price  Quantity   Sales  \
# ...

# %%
data= data.set_index('Orders Date')
data.index = pd.to_datetime(data.index)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Actual shipping days', 'Estimated shipping days',
#        'Delivery Status', 'Late_risk', 'Category', 'Customer City',
#        'Customer Segment', 'Department', 'Order Item Product Price',
#        'Quantity', 'Sales', 'Order Item Total', 'Order Status', 'Product Name',
#        'Product Price', 'Shipping date', 'Shipping Mode'],
#       dtype='object')

# %%
data.head()
# Out:
#                      Unnamed: 0  Actual shipping days  \
# Orders Date
# 2018-01-31 22:56:00           0                     3
# 2018-01-13 12:27:00           1                     5
# 2018-01-13 12:06:00           2                     4
# 2018-01-13 11:45:00           3                     3
# 2018-01-13 11:24:00           4                     2
#
#                      Estimated shipping days   Delivery Status  Late_risk  \
# Orders Date
# 2018-01-31 22:56:00                        4  Advance shipping          0
# 2018-01-13 12:27:00                        4     Late delivery          1
# 2018-01-13 12:06:00                        4  Shipping on time          0
# 2018-01-13 11:45:00                        4  Advance shipping          0
# 2018-01-13 11:24:00                        4  Advance shipping          0
#
#                            Category Customer City Customer Segment Department  \
# Orders Date
# ...

# %%
new_data= data[[ "Quantity","Category"]]

# %%
new_data.head()
# Out:
#                      Quantity        Category
# Orders Date
# 2018-01-31 22:56:00         1  Sporting Goods
# 2018-01-13 12:27:00         1  Sporting Goods
# 2018-01-13 12:06:00         1  Sporting Goods
# 2018-01-13 11:45:00         1  Sporting Goods
# 2018-01-13 11:24:00         1  Sporting Goods

# %%
new_data['dayofmonth'] = new_data.index.day
# Out:
# <ipython-input-9-9f3fdfe8a3ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['dayofmonth'] = new_data.index.day

# %%
new_data['date'] = new_data.index.date
# Out:
# <ipython-input-10-6b24f4e5e134>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['date'] = new_data.index.date

# %%
new_data['month'] = new_data.index.month
# Out:
# <ipython-input-11-5c08489adb8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['month'] = new_data.index.month

# %%
new_data['year'] = new_data.index.year
# Out:
# <ipython-input-12-b41d43b67f21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['year'] = new_data.index.year

# %%
new_data.head()
# Out:
#                      Quantity        Category  dayofmonth        date  month  \
# Orders Date
# 2018-01-31 22:56:00         1  Sporting Goods          31  2018-01-31      1
# 2018-01-13 12:27:00         1  Sporting Goods          13  2018-01-13      1
# 2018-01-13 12:06:00         1  Sporting Goods          13  2018-01-13      1
# 2018-01-13 11:45:00         1  Sporting Goods          13  2018-01-13      1
# 2018-01-13 11:24:00         1  Sporting Goods          13  2018-01-13      1
#
#                      year
# Orders Date
# 2018-01-31 22:56:00  2018
# 2018-01-13 12:27:00  2018
# 2018-01-13 12:06:00  2018
# 2018-01-13 11:45:00  2018
# 2018-01-13 11:24:00  2018

# %%
sort=new_data.sort_values(["year","month"])

# %%
sort.head(10)
# Out:
#                      Quantity         Category  dayofmonth        date  month  \
# Orders Date
# 2015-01-15 04:32:00         5    Shop By Sport          15  2015-01-15      1
# 2015-01-06 19:26:00         5           Cleats           6  2015-01-06      1
# 2015-01-30 09:14:00         2   Girls' Apparel          30  2015-01-30      1
# 2015-01-06 08:13:00         2    Shop By Sport           6  2015-01-06      1
# 2015-01-27 00:39:00         2  Women's Apparel          27  2015-01-27      1
# 2015-01-30 03:59:00         5  Women's Apparel          30  2015-01-30      1
# 2015-01-21 05:13:00         5    Shop By Sport          21  2015-01-21      1
# 2015-01-17 02:46:00         5      Electronics          17  2015-01-17      1
# 2015-01-27 05:13:00         5      Accessories          27  2015-01-27      1
# 2015-01-24 20:06:00         5      Accessories          24  2015-01-24      1
#
#                      year
# Orders Date
# 2015-01-15 04:32:00  2015
# 2015-01-06 19:26:00  2015
# ...

# %%
category= sort.groupby("Category")

# %%
category.size().sort_values(ascending=False)
# Out:
# Category
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport           10984
# Electronics              3156
# Accessories              1780
# Golf Balls               1475
# Girls' Apparel           1201
# Golf Gloves              1070
# Trade-In                  974
# Video Games               838
# Children's Clothing       652
# Women's Clothing          650
# Baseball & Softball       632
# Hockey                    614
# Cameras                   592
# Toys                      529
# Golf Shoes                524
# Pet Supplies              492
# Crafts                    484
# Garden                    484
# DVDs                      483
# Computers                 442
# Golf Apparel              441
# Hunting & Shooting        440
# ...

# %%
category.get_group('Cleats')
# Out:
#                      Quantity Category  dayofmonth        date  month  year
# Orders Date
# 2015-01-06 19:26:00         5   Cleats           6  2015-01-06      1  2015
# 2015-01-09 10:50:00         5   Cleats           9  2015-01-09      1  2015
# 2015-01-18 07:09:00         4   Cleats          18  2015-01-18      1  2015
# 2015-01-21 04:10:00         4   Cleats          21  2015-01-21      1  2015
# 2015-01-21 04:10:00         4   Cleats          21  2015-01-21      1  2015
# ...                       ...      ...         ...         ...    ...   ...
# 2017-10-02 10:40:00         3   Cleats           2  2017-10-02     10  2017
# 2017-10-01 23:49:00         5   Cleats           1  2017-10-01     10  2017
# 2017-10-01 07:42:00         4   Cleats           1  2017-10-01     10  2017
# 2017-10-01 22:25:00         3   Cleats           1  2017-10-01     10  2017
# 2017-10-01 22:25:00         3   Cleats           1  2017-10-01     10  2017
#
# [24551 rows x 6 columns]

# %%
new = category.get_group('Cleats')

# %%
new.head()
# Out:
#                      Quantity Category  dayofmonth        date  month  year
# Orders Date
# 2015-01-06 19:26:00         5   Cleats           6  2015-01-06      1  2015
# 2015-01-09 10:50:00         5   Cleats           9  2015-01-09      1  2015
# 2015-01-18 07:09:00         4   Cleats          18  2015-01-18      1  2015
# 2015-01-21 04:10:00         4   Cleats          21  2015-01-21      1  2015
# 2015-01-21 04:10:00         4   Cleats          21  2015-01-21      1  2015

# %%
new['date'] = pd.to_datetime(new['date'])
# Out:
# <ipython-input-21-1483fdbd2912>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['date'] = pd.to_datetime(new['date'])

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24551 entries, 2015-01-06 19:26:00 to 2017-10-01 22:25:00
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Quantity    24551 non-null  int64
#  1   Category    24551 non-null  object
#  2   dayofmonth  24551 non-null  int64
#  3   date        24551 non-null  datetime64[ns]
#  4   month       24551 non-null  int64
#  5   year        24551 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 1.3+ MB

# %%
new=new.reset_index()

# %%
new.head()
# Out:
#           Orders Date  Quantity Category  dayofmonth       date  month  year
# 0 2015-01-06 19:26:00         5   Cleats           6 2015-01-06      1  2015
# 1 2015-01-09 10:50:00         5   Cleats           9 2015-01-09      1  2015
# 2 2015-01-18 07:09:00         4   Cleats          18 2015-01-18      1  2015
# 3 2015-01-21 04:10:00         4   Cleats          21 2015-01-21      1  2015
# 4 2015-01-21 04:10:00         4   Cleats          21 2015-01-21      1  2015

# %%
time_data= new.groupby(['year','month','dayofmonth'])['Quantity'].sum()

# %%
time_data
# Out:
# year  month  dayofmonth
# 2015  1      1             68
#              2             77
#              3             73
#              4             88
#              5             90
#                            ..
# 2017  9      28            42
#              29            40
#              30            90
#       10     1             86
#              2             34
# Name: Quantity, Length: 1006, dtype: int64

# %%
time_data.to_csv(r"E:\Hochschule Ansbach\Thesis\DATA\time_series_cleats_New.csv")

# %%
time_data= pd.read_csv(r"E:\Hochschule Ansbach\Thesis\DATA\time_series_cleats_New.csv", usecols=['dayofmonth', 'Quantity','month'],squeeze=True)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=time_data, x='dayofmonth', y='Quantity')
ax.set_title('Daily Demand ')
plt.show()

# %%
#time_data= pd.read_csv(r"E:\Hochschule Ansbach\Thesis\DATA\time_series_cleats_New.csv", usecols=['Quantity','dayofmonth'],squeeze=True)

# %%
#time_data=pd.Series(new['Quantity'], new['date'] )

# %%
# printing 1st two month/1st 60 rows 
time_data.head(60)
# Out:
#     month  dayofmonth  Quantity
# 0       1           1        68
# 1       1           2        77
# 2       1           3        73
# 3       1           4        88
# 4       1           5        90
# 5       1           6        62
# 6       1           7        71
# 7       1           8        83
# 8       1           9        79
# 9       1          10        81
# 10      1          11        63
# 11      1          12       118
# 12      1          13        75
# 13      1          14        74
# 14      1          15        65
# 15      1          16        84
# 16      1          17        60
# 17      1          18        84
# 18      1          19        62
# 19      1          20        57
# 20      1          21       104
# 21      1          22        79
# 22      1          23        90
# 23      1          24        73
# 24      1          25        82
# 25      1          26        94
# 26      1          27        90
# 27      1          28        92
# ...

# %%
# Plotting demand
plt.plot(time_data["Quantity"])

plt.show()

# %%
# Plotting Janyray 2015
short=time_data.iloc[0:31]
plt.plot(short["Quantity"])

plt.xlabel("days")


plt.ylabel('Quantity')
plt.
plt.show()

# %%
# Plotting Feb 2015
short2=time_data.iloc[31:59]
plt.plot(short2["Quantity"])

plt.xlabel("days")


plt.ylabel('Quantity')
plt.show()

# %%
# making time series
ts = pd.Series(time_data["Quantity"].values, index=time_data["dayofmonth"].values)

# %%
# printing series 
ts
# Out:
# 1     68
# 2     77
# 3     73
# 4     88
# 5     90
#       ..
# 28    42
# 29    40
# 30    90
# 1     86
# 2     34
# Length: 1006, dtype: int64

# %%
# Sanity check  for series 
type(ts)
# Out:
# pandas.core.series.Series

# %%
# number of obserbation
len(ts)
# Out:
# 1006

# %% [markdown]
# # train-test split

# %%
# train data
ts_train=ts.iloc[0:800]
# test data
ts_test=ts.iloc[800:]

# %%
# number of obserbation in train data
len(ts_train)
# Out:
# 800

# %%
# number of obserbation in test data
len(ts_test)
# Out:
# 206

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# https://www.statsmodels.org/dev/examples/notebooks/generated/exponential_smoothing.html
# Simple Exponential Smoothing Method 
fit1 = SimpleExpSmoothing(ts_train).fit(optimized=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Fitted Values
fit1.fittedvalues
# Out:
# 1     76.957963
# 2     76.826880
# 3     76.829413
# 4     76.773377
# 5     76.937658
#         ...
# 6     75.004996
# 7     74.800058
# 8     75.241979
# 9     75.501836
# 10    75.406693
# Length: 800, dtype: float64

# %%
# Model Parameters 
fit1.params
# Out:
# {'smoothing_level': 0.014633186077208793,
#  'smoothing_trend': nan,
#  'smoothing_seasonal': nan,
#  'damping_trend': nan,
#  'initial_level': 76.95796334249347,
#  'initial_trend': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
# Model Parameters (Formated form)
fit1.params_formatted
# Out:
#                   name      param  optimized
# smoothing_level  alpha   0.014633       True
# initial_level      l.0  76.957963       True

# %%
# Model Selection Criteria (AIC, AICc, BIC)
#fit1.aic, fit1.aicc, fit1.bic
# Out:
# (4521.475899465588, 4521.526213930996, 4530.845122920923)

# %%
fcast1 = fit1.forecast(206)
fcast1
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 800     75.034912
# 801     75.034912
# 802     75.034912
# 803     75.034912
# 804     75.034912
#           ...
# 1001    75.034912
# 1002    75.034912
# 1003    75.034912
# 1004    75.034912
# 1005    75.034912
# Length: 206, dtype: float64

# %% [markdown]
# # Model Performance

# %%
# Casting into  list
fitted_values= list(fit1.fittedvalues)

# %%
# Casting into  list
ts_train= list(ts_train)

# %%
# Casting into  list  
forecast_values=list(fcast1)

# %%
# Casting into  list  
actual_values=list(ts_test)

# %% [markdown]
# #### Mean square error(MSE)
# https://www.educative.io/answers/calculating-mean-squared-error-in-python

# %%
# MSE for fitted values  values



summation = 0  #variable to store the summation of differences
n = len(actual_values) #finding total number of items in list
for i in range (0,n):  #looping through each element of the list
  difference = ts_train[i] - fitted_values[i]  #finding the difference between observed and predicted value
  squared_difference = difference**2  #taking square of the differene 
  summation = summation + squared_difference  #taking a sum of all the differences
MSE_train = summation/n  #dividing summation by total values to obtain average
print("The Mean Square Error is: " , MSE_train)
# Out:
# The Mean Square Error is:  303.00236067718544

# %%
# MSE for forecast values



summation = 0  #variable to store the summation of differences
n = len(actual_values) #finding total number of items in list
for i in range (0,n):  #looping through each element of the list
  difference = actual_values[i] - forecast_values[i]  #finding the difference between observed and predicted value
  squared_difference = difference**2  #taking square of the differene 
  summation = summation + squared_difference  #taking a sum of all the differences
MSE_test = summation/n  #dividing summation by total values to obtain average
print("The Mean Square Error is: " , MSE_test)
# Out:
# The Mean Square Error is:  282.0310087826004

# %% [markdown]
# #### Root Mean square error(RMSE)

# %%
# RMSE of train 
print("The Root Mean Square Error for train  is: " ,np.sqrt(MSE_train))
# Out:
# The Root Mean Square Error for train  is:  17.406962994077556

# %%
# RMSE of test
print("The Mean Square Errorfor test is: " ,np.sqrt(MSE_test))
# Out:
# The Mean Square Errorfor test is:  16.793778871433325

# %% [markdown]
# # R2
# https://www.askpython.com/python/coefficient-of-determination

# %%
# r2 for train data model 1
#actual = [1,2,3,4,5]
#predict = [1,2.5,3,4.9,4.9]
 
corr_matrix = np.corrcoef(ts_train, fitted_values)
corr = corr_matrix[0,1]
R_sq = corr**2

print(R_sq)
# Out:
# 0.00014227341068252106

# %%
# r2 for test data model 1
#actual = [1,2,3,4,5]
#predict = [1,2.5,3,4.9,4.9]
 
corr_matrix = np.corrcoef(actual_values, forecast_values)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)
# Out:
# 0.023338514409906908

# %% [markdown]
# # Holt’s Method

# %%
fit2 = Holt(ts_train, exponential=True).fit( optimized=True)

# %%
# Fitted Values
fit2.fittedvalues
# Out:
# array([79.14563189, 78.44446032, 79.41818055, 79.39054402, 82.20597631,
#        85.09388634, 82.07902886, 80.9131636 , 82.09669409, 82.31399158,
#        82.81866252, 79.66814661, 87.56085777, 86.30978345, 84.83136777,
#        81.61314735, 82.31867255, 78.25406489, 79.20021678, 75.79957701,
#        71.75969635, 77.29131482, 77.54005682, 79.93243926, 78.79818859,
#        79.49862774, 82.49085904, 84.43800565, 86.57368531, 82.18659708,
#        75.78065933, 73.05086453, 72.56351175, 66.99756742, 64.17778168,
#        62.72374403, 64.24702344, 67.90357253, 70.17204112, 66.65321566,
#        71.08093412, 76.98845713, 74.74454997, 70.86601708, 67.88532947,
#        63.84589385, 69.3764111 , 69.23180639, 65.41786154, 68.38742274,
#        74.12161031, 67.84488656, 74.4111446 , 73.96721483, 73.49313116,
#        74.77315639, 80.06748512, 75.82756112, 75.55404523, 75.44789922,
#        80.63853201, 83.41712054, 88.87920953, 88.45154433, 91.84566402,
# ...

# %%
# Model Parameters 
fit2.params
# Out:
# {'smoothing_level': 0.17421428720440182,
#  'smoothing_trend': 0.12195000104308126,
#  'smoothing_seasonal': nan,
#  'damping_trend': nan,
#  'initial_level': 77.6609375,
#  'initial_trend': 1.0191176470588235,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
# Model Parameters (Formated form)
fit2.params_formatted
# Out:
#                   name      param  optimized
# smoothing_level  alpha   0.174214       True
# smoothing_trend   beta   0.121950       True
# initial_level      l.0  77.660938       True
# initial_trend      b.0   1.019118       True

# %%
# Model Selection Criteria (AIC, AICc, BIC)
#fit1.aic, fit1.aicc, fit1.bic
# Out:
# (4521.475899465588, 4521.526213930996, 4530.845122920923)

# %%
fcast2 = fit2.forecast(206)
fcast2
# Out:
# array([73.27472024, 72.7618344 , 72.25253851, 71.74680742, 71.2446162 ,
#        70.74594007, 70.25075441, 69.7590348 , 69.27075698, 68.78589685,
#        68.3044305 , 67.82633417, 67.35158427, 66.88015738, 66.41203024,
#        65.94717975, 65.48558298, 65.02721715, 64.57205965, 64.12008802,
#        63.67127996, 63.22561333, 62.78306614, 62.34361656, 61.9072429 ,
#        61.47392363, 61.04363738, 60.61636292, 60.19207916, 59.77076517,
#        59.35240016, 58.9369635 , 58.52443468, 58.11479335, 57.70801931,
#        57.30409248, 56.90299293, 56.50470087, 56.10919666, 55.71646077,
#        55.32647384, 54.93921661, 54.55466999, 54.172815  , 53.79363281,
#        53.41710469, 53.04321208, 52.67193653, 52.30325972, 51.93716346,
#        51.57362969, 51.21264047, 50.85417799, 50.49822457, 50.14476264,
#        49.79377476, 49.44524362, 49.09915202, 48.75548289, 48.41421927,
#        48.07534431, 47.73884132, 47.40469367, 47.07288488, 46.74339859,
# ...

# %% [markdown]
# # Model Performance

# %%
# Casting into  list
fitted_values= list(fit2.fittedvalues)

# %%
# Casting into  list
ts_train= list(ts_train)

# %%
# Casting into  list  
forecast_values=list(fcast2)

# %%
# Casting into  list  
actual_values=list(ts_test)

# %% [markdown]
# #### Mean square error(MSE)
# https://www.educative.io/answers/calculating-mean-squared-error-in-python

# %%
# MSE for fitted values  values



summation = 0  #variable to store the summation of differences
n = len(actual_values) #finding total number of items in list
for i in range (0,n):  #looping through each element of the list
  difference = ts_train[i] - fitted_values[i]  #finding the difference between observed and predicted value
  squared_difference = difference**2  #taking square of the differene 
  summation = summation + squared_difference  #taking a sum of all the differences
MSE_train = summation/n  #dividing summation by total values to obtain average
print("The Mean Square Error is: " , MSE_train)
# Out:
# The Mean Square Error is:  356.6539205450524

# %%
# MSE for forecast values



summation = 0  #variable to store the summation of differences
n = len(actual_values) #finding total number of items in list
for i in range (0,n):  #looping through each element of the list
  difference = actual_values[i] - forecast_values[i]  #finding the difference between observed and predicted value
  squared_difference = difference**2  #taking square of the differene 
  summation = summation + squared_difference  #taking a sum of all the differences
MSE_test = summation/n  #dividing summation by total values to obtain average
print("The Mean Square Error is: " , MSE_test)
# Out:
# The Mean Square Error is:  1575.552111116782

# %% [markdown]
# #### Root Mean square error(RMSE)

# %%
# RMSE of train 
print("The Root Mean Square Error for train  is: " ,np.sqrt(MSE_train))
# Out:
# The Root Mean Square Error for train  is:  18.885283173546867

# %%
# RMSE of test
print("The Mean Square Errorfor test is: " ,np.sqrt(MSE_test))
# Out:
# The Mean Square Errorfor test is:  39.69322500272285

# %% [markdown]
# # Holt’s Winters Seasonal

# %%
# Fit the Holt’s Winters Seasonal: 4 different models 
fit3 = ExponentialSmoothing(ts_train, seasonal_periods=12,  trend='add', seasonal='add').fit()
fit4 = ExponentialSmoothing(ts_train, seasonal_periods=12, trend='add', seasonal='mul').fit()


fit5 = ExponentialSmoothing(ts_train, seasonal_periods=12, trend='add',seasonal='add', damped=True).fit()
fit6 = ExponentialSmoothing(ts_train, seasonal_periods=12, trend='add', seasonal='mul', damped=True).fit()
# Out:
# <ipython-input-498-22202b689f57>:6: FutureWarning: the 'damped'' keyword is deprecated, use 'damped_trend' instead
#   fit5 = ExponentialSmoothing(ts_train, seasonal_periods=12, trend='add',seasonal='add', damped=True).fit()
# <ipython-input-498-22202b689f57>:7: FutureWarning: the 'damped'' keyword is deprecated, use 'damped_trend' instead
#   fit6 = ExponentialSmoothing(ts_train, seasonal_periods=12, trend='add', seasonal='mul', damped=True).fit()

# %%
# Fitted Values
fit3.fittedvalues
# Out:
# array([76.27730494, 81.12270974, 72.78063146, 83.07116913, 76.16010144,
#        69.80057468, 72.01390513, 77.23711124, 74.08940826, 77.15886907,
#        76.74187992, 80.76312699, 76.53277974, 81.93424249, 73.7649415 ,
#        84.05300629, 77.55994133, 68.60865903, 72.14229858, 77.47597536,
#        73.28191847, 77.24655914, 75.60298357, 84.03843318, 75.45905858,
#        80.73561821, 73.31116531, 85.14759573, 77.79945915, 71.03512602,
#        71.47152252, 76.23510286, 76.09781432, 75.91467585, 74.32919091,
#        80.08114385, 72.89724529, 78.88667771, 71.25496551, 81.06564139,
#        72.17517694, 66.75975088, 68.86829917, 73.62845314, 71.11125285,
#        71.88023453, 72.2814986 , 78.87128057, 71.89809289, 76.9274792 ,
#        68.55151915, 79.83554315, 72.52423299, 63.66745555, 65.39452863,
#        71.09174659, 70.00292044, 74.02521401, 71.66993642, 76.76947498,
#        74.41085129, 80.32033541, 68.8220351 , 85.02922683, 75.77697445,
# ...

# %%
# Fitted Values
fit4.fittedvalues
# Out:
# array([80.41024281, 84.88011343, 78.00793115, 89.53297472, 79.54648443,
#        73.74197767, 75.20764128, 80.882273  , 78.19933824, 79.62919732,
#        79.97413386, 87.41370982, 78.31449355, 83.35617015, 76.6877578 ,
#        87.97782054, 78.82634859, 70.6598738 , 73.5181262 , 79.16473198,
#        75.53058379, 78.01402571, 77.1510053 , 88.75002578, 75.95166242,
#        80.83143303, 74.95150767, 87.78810369, 77.95407232, 71.898697  ,
#        71.68162681, 76.70111574, 77.10820319, 75.50817126, 74.67565375,
#        82.90020489, 72.39839932, 77.82428224, 71.99184473, 81.93829477,
#        71.58391405, 67.17187731, 68.6267014 , 73.40579844, 71.48170084,
#        70.91517029, 72.07194832, 80.80594968, 71.0183992 , 75.38806178,
#        68.93190879, 79.91724608, 71.52601405, 63.91105851, 65.01706142,
#        70.6457534 , 70.15526058, 72.92222572, 71.2447344 , 78.32357524,
#        73.24251636, 78.63572497, 68.65715449, 85.3386259 , 74.55558372,
# ...

# %%
# Fitted Values
fit5.fittedvalues
# Out:
# array([87.98587184, 91.84017487, 66.00437953, 97.28578966, 76.80792596,
#        70.57670087, 66.54257044, 71.25171601, 74.01557913, 83.08164734,
#        75.73663439, 83.52352912, 85.81366229, 90.4079604 , 66.02196057,
#        95.87736136, 76.84825394, 67.91513657, 65.78065535, 70.6649979 ,
#        71.93912215, 81.62226583, 73.53328626, 85.7527004 , 83.03414467,
#        87.64499664, 65.24500217, 95.41757399, 76.41248638, 69.77749094,
#        64.76372336, 69.10391885, 74.2789639 , 79.18762514, 71.6498373 ,
#        80.83672588, 79.26847874, 84.77046256, 63.25092241, 90.05582564,
#        70.35484375, 65.24542533, 62.41992447, 66.79569878, 69.12394291,
#        74.73334897, 69.77680759, 79.62202312, 77.87659958, 82.44555144,
#        61.15987714, 88.32296107, 71.0696144 , 62.31277247, 59.46435728,
#        64.88267648, 68.40728116, 77.06825309, 69.55309918, 77.60821429,
#        80.37714494, 85.87701455, 62.18541602, 93.38479097, 74.72994429,
# ...

# %%
# Fitted Values
fit6.fittedvalues
# Out:
# array([89.04223575, 92.81620237, 81.40225617, 97.82907823, 82.9747162 ,
#        75.75121978, 77.92018662, 83.55229723, 80.42536577, 82.8112636 ,
#        81.80814887, 86.9125013 , 82.9857941 , 87.41018656, 77.08315757,
#        92.46789336, 79.47055903, 70.29714731, 73.90195731, 79.47077886,
#        75.59368703, 79.06420007, 77.06728322, 86.62723944, 78.56495203,
#        82.90719812, 73.96164826, 90.49668663, 77.30641962, 70.55715829,
#        70.90594507, 75.81417615, 76.25036681, 75.40221925, 73.66519143,
#        79.96843381, 73.90358408, 78.94255278, 70.55866156, 83.58080593,
#        70.46565238, 65.60431874, 67.69158783, 72.40057746, 70.44349561,
#        70.6472292 , 71.11528718, 78.1530831 , 72.40874064, 76.42390635,
#        67.63238693, 81.49591631, 70.70210851, 62.53393963, 64.22089985,
#        69.8620487 , 69.39331802, 73.0457908 , 70.56450272, 75.99694886,
#        74.95792579, 80.03774745, 67.56168157, 87.34157551, 73.99759139,
# ...

# %%
# Model Parameters 
fit3.params
# Out:
# {'smoothing_level': 0.03719470723533213,
#  'smoothing_trend': 0.02075396516641662,
#  'smoothing_seasonal': 0.06555838418675568,
#  'damping_trend': nan,
#  'initial_level': 77.06213687766109,
#  'initial_trend': -0.045794142664047154,
#  'initial_seasons': array([-0.7390378 ,  4.46642265, -3.66694647,  6.67062869, -0.37237333,
#         -7.20596251, -4.65576186,  0.65266894, -2.66631881,  0.2597675 ,
#         -0.26378298,  4.31550557]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
# Model Parameters 
fit4.params
# Out:
# {'smoothing_level': 0.03838252579962973,
#  'smoothing_trend': 0.014577393990288167,
#  'smoothing_seasonal': 0.06527228261000881,
#  'damping_trend': nan,
#  'initial_level': 76.21066160826058,
#  'initial_trend': -0.033673842673313005,
#  'initial_seasons': array([1.05557131, 1.12148483, 1.03497781, 1.19156485, 1.06002624,
#         0.97829038, 1.00452422, 1.08338509, 1.04709807, 1.06653369,
#         1.07114764, 1.1813288 ]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
# Model Parameters 
fit5.params
# Out:
# {'smoothing_level': 0.04036577163053637,
#  'smoothing_trend': 0.008074581856704696,
#  'smoothing_seasonal': 0.06854393079402167,
#  'damping_trend': 0.9900002211493326,
#  'initial_level': 80.27034070394669,
#  'initial_trend': -0.09518300129421609,
#  'initial_seasons': array([  7.80976233,  12.57054839, -12.56268272,  18.53658032,
#          -1.46422481,  -8.13100672, -11.72018256,  -7.09464091,
#          -4.7134368 ,   4.24047692,  -2.93168195,   5.4613852 ]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
# Model Parameters 
fit6.params
# Out:
# {'smoothing_level': 0.04041760825374209,
#  'smoothing_trend': 0.00010089287345504688,
#  'smoothing_seasonal': 0.06859313141712929,
#  'damping_trend': 0.9899978919458489,
#  'initial_level': 80.26503813944444,
#  'initial_trend': -0.17227679975106813,
#  'initial_seasons': array([1.11171495, 1.17250583, 1.03765805, 1.25494083, 1.07099325,
#         0.97646099, 1.01396083, 1.09344071, 1.05497686, 1.08928376,
#         1.07923624, 1.15969144]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
# Model Parameters (Formated form)
fit3.params_formatted
# Out:
#                      name      param  optimized
# smoothing_level     alpha   0.037195       True
# smoothing_trend      beta   0.020754       True
# smoothing_seasonal  gamma   0.065558       True
# initial_level         l.0  77.062137       True
# initial_trend         b.0  -0.045794       True
# initial_seasons.0     s.0  -0.739038       True
# initial_seasons.1     s.1   4.466423       True
# initial_seasons.2     s.2  -3.666946       True
# initial_seasons.3     s.3   6.670629       True
# initial_seasons.4     s.4  -0.372373       True
# initial_seasons.5     s.5  -7.205963       True
# initial_seasons.6     s.6  -4.655762       True
# initial_seasons.7     s.7   0.652669       True
# initial_seasons.8     s.8  -2.666319       True
# initial_seasons.9     s.9   0.259767       True
# initial_seasons.10   s.10  -0.263783       True
# initial_seasons.11   s.11   4.315506       True

# %%
# Model Parameters (Formated form)
fit4.params_formatted
# Out:
#                      name      param  optimized
# smoothing_level     alpha   0.038383       True
# smoothing_trend      beta   0.014577       True
# smoothing_seasonal  gamma   0.065272       True
# initial_level         l.0  76.210662       True
# initial_trend         b.0  -0.033674       True
# initial_seasons.0     s.0   1.055571       True
# initial_seasons.1     s.1   1.121485       True
# initial_seasons.2     s.2   1.034978       True
# initial_seasons.3     s.3   1.191565       True
# initial_seasons.4     s.4   1.060026       True
# initial_seasons.5     s.5   0.978290       True
# initial_seasons.6     s.6   1.004524       True
# initial_seasons.7     s.7   1.083385       True
# initial_seasons.8     s.8   1.047098       True
# initial_seasons.9     s.9   1.066534       True
# initial_seasons.10   s.10   1.071148       True
# initial_seasons.11   s.11   1.181329       True

# %%
# Model Parameters (Formated form)
fit5.params_formatted
# Out:
#                      name      param  optimized
# smoothing_level     alpha   0.040366       True
# smoothing_trend      beta   0.008075       True
# smoothing_seasonal  gamma   0.068544       True
# initial_level         l.0  80.270341       True
# initial_trend         b.0  -0.094231       True
# damping_trend         phi   0.990000       True
# initial_seasons.0     s.0   7.809762       True
# initial_seasons.1     s.1  12.570548       True
# initial_seasons.2     s.2 -12.562683       True
# initial_seasons.3     s.3  18.536580       True
# initial_seasons.4     s.4  -1.464225       True
# initial_seasons.5     s.5  -8.131007       True
# initial_seasons.6     s.6 -11.720183       True
# initial_seasons.7     s.7  -7.094641       True
# initial_seasons.8     s.8  -4.713437       True
# initial_seasons.9     s.9   4.240477       True
# initial_seasons.10   s.10  -2.931682       True
# initial_seasons.11   s.11   5.461385       True

# %%
# Model Parameters (Formated form)
fit6.params_formatted
# Out:
#                      name      param  optimized
# smoothing_level     alpha   0.040418       True
# smoothing_trend      beta   0.000101       True
# smoothing_seasonal  gamma   0.068593       True
# initial_level         l.0  80.265038       True
# initial_trend         b.0  -0.170554       True
# damping_trend         phi   0.989998       True
# initial_seasons.0     s.0   1.111715       True
# initial_seasons.1     s.1   1.172506       True
# initial_seasons.2     s.2   1.037658       True
# initial_seasons.3     s.3   1.254941       True
# initial_seasons.4     s.4   1.070993       True
# initial_seasons.5     s.5   0.976461       True
# initial_seasons.6     s.6   1.013961       True
# initial_seasons.7     s.7   1.093441       True
# initial_seasons.8     s.8   1.054977       True
# initial_seasons.9     s.9   1.089284       True
# initial_seasons.10   s.10   1.079236       True
# initial_seasons.11   s.11   1.159691       True

# %%
# forecast
fcast3 = fit3.forecast(206)
fcast3
# Out:
# array([80.61020803, 72.892631  , 78.67299695, 71.8021547 , 76.66143592,
#        76.88992163, 74.45155755, 74.47268852, 81.83123449, 71.62371247,
#        76.06960708, 74.8826865 , 80.75136514, 73.03378811, 78.81415406,
#        71.94331181, 76.80259303, 77.03107874, 74.59271465, 74.61384563,
#        81.9723916 , 71.76486958, 76.21076419, 75.02384361, 80.89252225,
#        73.17494522, 78.95531117, 72.08446892, 76.94375014, 77.17223585,
#        74.73387176, 74.75500273, 82.11354871, 71.90602668, 76.3519213 ,
#        75.16500072, 81.03367936, 73.31610233, 79.09646828, 72.22562602,
#        77.08490725, 77.31339296, 74.87502887, 74.89615984, 82.25470582,
#        72.04718379, 76.49307841, 75.30615783, 81.17483646, 73.45725944,
#        79.23762539, 72.36678313, 77.22606436, 77.45455007, 75.01618598,
#        75.03731695, 82.39586293, 72.1883409 , 76.63423552, 75.44731494,
#        81.31599357, 73.59841655, 79.3787825 , 72.50794024, 77.36722147,
# ...

# %%
# forecast
fcast4 = fit4.forecast(206)
fcast4
# Out:
# array([80.95461156, 72.9262907 , 78.91483628, 72.0015097 , 76.85163779,
#        77.10778069, 74.80911303, 74.57240609, 82.01587957, 71.77121647,
#        76.25452521, 75.0599768 , 81.10142105, 73.05852102, 79.05790344,
#        72.13202376, 76.99092243, 77.24750846, 74.94465489, 74.70749868,
#        82.16443406, 71.90119529, 76.39260253, 75.1958706 , 81.24823055,
#        73.19075134, 79.20097061, 72.26253782, 77.13020707, 77.38723622,
#        75.08019675, 74.84259127, 82.31298854, 72.0311741 , 76.53067985,
#        75.33176439, 81.39504005, 73.32298166, 79.34403777, 72.39305189,
#        77.26949171, 77.52696399, 75.21573861, 74.97768387, 82.46154302,
#        72.16115292, 76.66875717, 75.46765819, 81.54184954, 73.45521198,
#        79.48710494, 72.52356595, 77.40877636, 77.66669176, 75.35128048,
#        75.11277646, 82.61009751, 72.29113174, 76.80683449, 75.60355198,
#        81.68865904, 73.5874423 , 79.6301721 , 72.65408001, 77.548061  ,
# ...

# %%
# forecast
fcast5 = fit5.forecast(206)
fcast5
# Out:
# array([80.60869145, 72.85751107, 78.52280832, 71.66729851, 76.57468324,
#        76.86225922, 74.20857604, 74.4328473 , 81.93016628, 71.40216   ,
#        75.94893957, 74.62186187, 80.66117104, 72.90946588, 78.57424359,
#        71.71821944, 76.62509497, 76.91216684, 74.2579846 , 74.48176178,
#        81.97859164, 71.45010111, 75.99640127, 74.66884897, 80.70768828,
#        72.95551796, 78.61983515, 71.7633551 , 76.66977928, 76.95640432,
#        74.30177972, 74.52511896, 82.02151525, 71.49259549, 76.03847073,
#        74.71049773, 80.74892057, 72.99633793, 78.66024694, 71.80336278,
#        76.70938689, 76.99561586, 74.34059915, 74.5635502 , 82.05956219,
#        71.53026198, 76.07576055, 74.74741467, 80.78546835, 73.03252023,
#        78.69606743, 71.83882507, 76.74449457, 77.03037247, 74.3750082 ,
#        74.59761517, 82.09328652, 71.56364907, 76.10881378, 74.78013737,
#        80.81786383, 73.06459177, 78.72781825, 71.87025839, 76.77561357,
# ...

# %%
# forecast
fcast5 = fit5.forecast(206)
fcast5
# Out:
# array([80.60869145, 72.85751107, 78.52280832, 71.66729851, 76.57468324,
#        76.86225922, 74.20857604, 74.4328473 , 81.93016628, 71.40216   ,
#        75.94893957, 74.62186187, 80.66117104, 72.90946588, 78.57424359,
#        71.71821944, 76.62509497, 76.91216684, 74.2579846 , 74.48176178,
#        81.97859164, 71.45010111, 75.99640127, 74.66884897, 80.70768828,
#        72.95551796, 78.61983515, 71.7633551 , 76.66977928, 76.95640432,
#        74.30177972, 74.52511896, 82.02151525, 71.49259549, 76.03847073,
#        74.71049773, 80.74892057, 72.99633793, 78.66024694, 71.80336278,
#        76.70938689, 76.99561586, 74.34059915, 74.5635502 , 82.05956219,
#        71.53026198, 76.07576055, 74.74741467, 80.78546835, 73.03252023,
#        78.69606743, 71.83882507, 76.74449457, 77.03037247, 74.3750082 ,
#        74.59761517, 82.09328652, 71.56364907, 76.10881378, 74.78013737,
#        80.81786383, 73.06459177, 78.72781825, 71.87025839, 76.77561357,
# ...

# %%
# forecast
fcast6 = fit6.forecast(206)
fcast6
# Out:
# array([80.89128971, 72.7903937 , 78.67901531, 71.72676801, 76.60342707,
#        76.89219379, 74.47563508, 74.32501828, 81.98001009, 71.40925937,
#        76.05834579, 74.69605255, 80.89161557, 72.79068398, 78.67932594,
#        71.72704837, 76.60372349, 76.89248835, 74.47591752, 74.32529734,
#        81.98031481, 71.40952214, 76.05862287, 74.69632195, 80.89190439,
#        72.79094128, 78.67960128, 71.72729686, 76.60398622, 76.89274944,
#        74.47616788, 74.32554469, 81.9805849 , 71.40975505, 76.05886846,
#        74.69656073, 80.89216039, 72.79116935, 78.67984532, 71.72751712,
#        76.6042191 , 76.89298085, 74.47638978, 74.32576392, 81.9808243 ,
#        71.4099615 , 76.05908615, 74.69677238, 80.8923873 , 72.79137149,
#        78.68006163, 71.72771234, 76.60442551, 76.89318597, 74.47658646,
#        74.32595825, 81.98103649, 71.41014448, 76.0592791 , 74.69695998,
#        80.89258843, 72.79155066, 78.68025337, 71.72788538, 76.60460847,
# ...

# %%
# Models parameters and Model selection
# SSE = Sum square error
# minimum AIC BIC give the better result
results=pd.DataFrame(index=[r"$\alpha$",r"$\beta$",r"$\phi$",r"$\gamma$",r"$l_0$","$b_0$","SSE", "AIC","BIC"])
params = ['smoothing_level', 'smoothing_trend', 'damping_trend', 'smoothing_seasonal', 'initial_level', 'initial_trend']


results["Model-1"] = [fit1.params[p] for p in params] + [fit1.sse] + [fit1.aic] + [fit1.bic]
results["Model-2"] = [fit2.params[p] for p in params] + [fit2.sse] + [fit2.aic] + [fit2.bic]
results["Model-3"] = [fit3.params[p] for p in params] + [fit3.sse] + [fit3.aic] + [fit3.bic]
results["Model-4"] = [fit4.params[p] for p in params] + [fit4.sse] + [fit4.aic] + [fit4.bic]
results["Model-5"] = [fit5.params[p] for p in params] + [fit5.sse] + [fit5.aic] + [fit5.bic]
results["Model-6"] = [fit6.params[p] for p in params] + [fit6.sse] + [fit6.aic] + [fit6.bic]
results
# Out:
#                 Model-1        Model-2        Model-3        Model-4  \
# $\alpha$       0.014633       0.174214       0.037195       0.038383
# $\beta$             NaN       0.121950       0.020754       0.014577
# $\phi$              NaN            NaN            NaN            NaN
# $\gamma$            NaN            NaN       0.065558       0.065272
# $l_0$         76.957963      77.660938      77.062137      76.210662
# $b_0$               NaN       1.019118      -0.045794      -0.033674
# SSE       226716.723257  267895.727744  237518.835897  237809.122198
# AIC         4521.475899    4658.993104    4586.712385    4587.689517
# BIC         4530.845123    4677.731551    4661.666172    4662.643304
#
#                 Model-5        Model-6
# $\alpha$       0.040366       0.040418
# $\beta$        0.008075       0.000101
# $\phi$         0.990000       0.989998
# $\gamma$       0.068544       0.068593
# $l_0$         80.270341      80.265038
# ...

# %% [markdown]
# # Model 3 has lower AIC  and BIC after Model 1
# # lets check it's MSE RMSE R2

# %%
# Casting into  list
fitted_values= list(fit3.fittedvalues)

# %%
# Casting into  list
ts_train= list(ts_train)

# %%
# Casting into  list  
forecast_values=list(fcast3)

# %%
# Casting into  list  
actual_values=list(ts_test)

# %% [markdown]
# #### Mean square error(MSE)
# https://www.educative.io/answers/calculating-mean-squared-error-in-python

# %%
# MSE for fitted values  values



summation = 0  #variable to store the summation of differences
n = len(actual_values) #finding total number of items in list
for i in range (0,n):  #looping through each element of the list
  difference = ts_train[i] - fitted_values[i]  #finding the difference between observed and predicted value
  squared_difference = difference**2  #taking square of the differene 
  summation = summation + squared_difference  #taking a sum of all the differences
MSE_train = summation/n  #dividing summation by total values to obtain average
print("The Mean Square Error is: " , MSE_train)
# Out:
# The Mean Square Error is:  305.3032479065714

# %%
# MSE for forecast values



summation = 0  #variable to store the summation of differences
n = len(actual_values) #finding total number of items in list
for i in range (0,n):  #looping through each element of the list
  difference = actual_values[i] - forecast_values[i]  #finding the difference between observed and predicted value
  squared_difference = difference**2  #taking square of the differene 
  summation = summation + squared_difference  #taking a sum of all the differences
MSE_test = summation/n  #dividing summation by total values to obtain average
print("The Mean Square Error is: " , MSE_test)
# Out:
# The Mean Square Error is:  295.40430490199793

# %% [markdown]
# #### Root Mean square error(RMSE)

# %%
# RMSE of train 
print("The Root Mean Square Error for train  is: " ,np.sqrt(MSE_train))
# Out:
# The Root Mean Square Error for train  is:  17.472929001932428

# %%
# RMSE of test
print("The Mean Square Errorfor test is: " ,np.sqrt(MSE_test))
# Out:
# The Mean Square Errorfor test is:  17.18732977812429

# %% [markdown]
# # R2
# https://www.askpython.com/python/coefficient-of-determination

# %%
# r2 for train data model 3 
#actual = [1,2,3,4,5]
#predict = [1,2.5,3,4.9,4.9]
 
corr_matrix = np.corrcoef(ts_train, fitted_values)
corr = corr_matrix[0,1]
R_sq = corr**2

print(R_sq)
# Out:
# 0.00014227341068252106

# %%
# r2 for test data model 3
#actual = [1,2,3,4,5]
#predict = [1,2.5,3,4.9,4.9]
 
corr_matrix = np.corrcoef(actual_values, forecast_values)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)
# Out:
# 0.023338514409906908

# %% [raw]
# # r2 for train data model 3
# from sklearn.metrics import r2_score
# #a =[1, 2, 3, 4, 5]
# #b =[1, 2.5, 3, 4.9, 5.1]
#
# R_square = r2_score(ts_train, fitted_values)
# print('Coefficient of Determination', R_square)

# %% [raw]
# # r2 for test data model 3
# from sklearn.metrics import r2_score
# #a =[1, 2, 3, 4, 5]
# #b =[1, 2.5, 3, 4.9, 5.1]
#
# R_square = r2_score(actual_values, forecast_values)
# print('Coefficient of Determination', R_square)
