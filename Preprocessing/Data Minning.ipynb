# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\Hochschule Ansbach\Thesis\DATA\SCM_data.csv ")

# %% [markdown]
# # Unnamed column name handle
#
# df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
#
#
#
#
# https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe

# %%
# Obser first few rows
df.head()
# Out:
#    Unnamed: 0  Actual shipping days  Estimated shipping days  \
# 0           0                     3                        4
# 1           1                     5                        4
# 2           2                     4                        4
# 3           3                     3                        4
# 4           4                     2                        4
#
#     Delivery Status  Late_risk        Category Customer City Customer Segment  \
# 0  Advance shipping          0  Sporting Goods        Caguas         Consumer
# 1     Late delivery          1  Sporting Goods        Caguas         Consumer
# 2  Shipping on time          0  Sporting Goods      San Jose         Consumer
# 3  Advance shipping          0  Sporting Goods   Los Angeles      Home Office
# 4  Advance shipping          0  Sporting Goods        Caguas        Corporate
#
#   Department      Orders Date  Order Item Product Price  Quantity   Sales  \
# ...

# %%
# Columns names 
df.columns
# Out:
# Index(['Unnamed: 0', 'Actual shipping days', 'Estimated shipping days',
#        'Delivery Status', 'Late_risk', 'Category', 'Customer City',
#        'Customer Segment', 'Department', 'Orders Date',
#        'Order Item Product Price', 'Quantity', 'Sales', 'Order Item Total',
#        'Order Status', 'Product Name', 'Product Price', 'Shipping date',
#        'Shipping Mode'],
#       dtype='object')

# %%
from platform import python_version
python_version()
# Out:
# '3.8.5'

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
# drop the index column
df = df.drop('Unnamed: 0', axis=1)

# %%
# Print the header

df.head()
# Out:
#    Actual shipping days  Estimated shipping days   Delivery Status  Late_risk  \
# 0                     3                        4  Advance shipping          0
# 1                     5                        4     Late delivery          1
# 2                     4                        4  Shipping on time          0
# 3                     3                        4  Advance shipping          0
# 4                     2                        4  Advance shipping          0
#
#          Category Customer City Customer Segment Department      Orders Date  \
# 0  Sporting Goods        Caguas         Consumer    Fitness  1/31/2018 22:56
# 1  Sporting Goods        Caguas         Consumer    Fitness  1/13/2018 12:27
# 2  Sporting Goods      San Jose         Consumer    Fitness  1/13/2018 12:06
# 3  Sporting Goods   Los Angeles      Home Office    Fitness  1/13/2018 11:45
# 4  Sporting Goods        Caguas        Corporate    Fitness  1/13/2018 11:24
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Actual shipping days      180519 non-null  int64
#  1   Estimated shipping days   180519 non-null  int64
#  2   Delivery Status           180519 non-null  object
#  3   Late_risk                 180519 non-null  int64
#  4   Category                  180519 non-null  object
#  5   Customer City             180519 non-null  object
#  6   Customer Segment          180519 non-null  object
#  7   Department                180519 non-null  object
#  8   Orders Date               180519 non-null  object
#  9   Order Item Product Price  180519 non-null  float64
#  10  Quantity                  180519 non-null  int64
#  11  Sales                     180519 non-null  float64
#  12  Order Item Total          180519 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Actual shipping days  Estimated shipping days      Late_risk  \
# count         180519.000000            180519.000000  180519.000000
# mean               3.497654                 2.931847       0.548291
# std                1.623722                 1.374449       0.497664
# min                0.000000                 0.000000       0.000000
# 25%                2.000000                 2.000000       0.000000
# 50%                3.000000                 4.000000       1.000000
# 75%                5.000000                 4.000000       1.000000
# max                6.000000                 4.000000       1.000000
#
#        Order Item Product Price       Quantity          Sales  \
# count             180519.000000  180519.000000  180519.000000
# mean                 141.232550       2.127638     203.772096
# std                  139.732492       1.453451     132.273077
# min                    9.990000       1.000000       9.990000
# ...

# %% [markdown]
# 1.'Actual shipping days'  column  will be my target variabel while predict the lead time .
#
# 2. According to product category ,how many of  these  product category we need in each  week or month. it will depends on my model complexity. and the further research will be the prdict demand according to each 'product name'

# %% [markdown]
# # International Dataframe

# %%
# Import all necessary library
import pandas as pd 
import numpy as np
# visualize the missing values
import missingno as msno

# Visualisation library
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data and observe the Numerical EDA

# %%
df_international=pd.read_csv(r"E:\Hochschule Ansbach\Thesis\DATA\df_international.csv ")

# %%
# drop the index column
df_international = df_international.drop('Unnamed: 0', axis=1)

# %%
# Print the header

df_international.head()
# Out:
#    Actual shipping days  Estimated shipping days   Delivery Status  Late_risk  \
# 0                     3                        4  Advance shipping          0
# 1                     5                        4     Late delivery          1
# 2                     4                        4  Shipping on time          0
# 3                     3                        4  Advance shipping          0
# 4                     2                        4  Advance shipping          0
#
#          Category  Order City    Order Region      Order State  \
# 0  Sporting Goods      Bekasi  Southeast Asia  Java Occidental
# 1  Sporting Goods     Bikaner      South Asia         Rajastán
# 2  Sporting Goods     Bikaner      South Asia         Rajastán
# 3  Sporting Goods  Townsville         Oceania       Queensland
# 4  Sporting Goods  Townsville         Oceania       Queensland
#
#   Customer Segment Department      Orders Date  Order Item Product Price  \
# ...

# %%
df_international.dtypes
# Out:
# Actual shipping days          int64
# Estimated shipping days       int64
# Delivery Status              object
# Late_risk                     int64
# Category                     object
# Order City                   object
# Order Region                 object
# Order State                  object
# Customer Segment             object
# Department                   object
# Orders Date                  object
# Order Item Product Price    float64
# Quantity                      int64
# Sales                       float64
# Order Item Total            float64
# Order Status                 object
# Product Name                 object
# Product Price               float64
# Shipping date                object
# Shipping Mode                object
# dtype: object

# %%
#dimension of dataframe
df_international.shape
# Out:
# (180519, 20)

# %%
# The describe method for non-numeric columns
df_international.describe(exclude='number')
# Out:
#        Delivery Status Category     Order City     Order Region Order State  \
# count           180519   180519         180519           180519      180519
# unique               4       50           3597               23        1089
# top      Late delivery   Cleats  Santo Domingo  Central America  Inglaterra
# freq             98977    24551           2211            28341        6722
#
#        Customer Segment Department       Orders Date Order Status  \
# count            180519     180519            180519       180519
# unique                3         11             65752            9
# top            Consumer   Fan Shop  11/24/2016 21:16     COMPLETE
# freq              93504      66861                 5        59491
#
#                             Product Name     Shipping date   Shipping Mode
# count                             180519            180519          180519
# unique                               118             63701               4
# ...

# %%
#Checking  the data types
df_international.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Actual shipping days      180519 non-null  int64
#  1   Estimated shipping days   180519 non-null  int64
#  2   Delivery Status           180519 non-null  object
#  3   Late_risk                 180519 non-null  int64
#  4   Category                  180519 non-null  object
#  5   Order City                180519 non-null  object
#  6   Order Region              180519 non-null  object
#  7   Order State               180519 non-null  object
#  8   Customer Segment          180519 non-null  object
#  9   Department                180519 non-null  object
#  10  Orders Date               180519 non-null  object
#  11  Order Item Product Price  180519 non-null  float64
#  12  Quantity                  180519 non-null  int64
# ...

# %% [markdown]
# # EDA

# %%
# what is the most frequent quantity people ordered
df_international.Quantity.value_counts().sort_values(ascending=False)
# Out:
# 1    99134
# 5    20385
# 3    20350
# 4    20335
# 2    20315
# Name: Quantity, dtype: int64

# %%
#vizualize the 'Quantity' column 
df_international.Quantity.value_counts().sort_values().plot(kind='bar', rot=0, xlabel="Quantity- number of product oder" , ylabel='Count' , )
# Out:
# <AxesSubplot:xlabel='Quantity- number of product oder', ylabel='Count'>

# %%
#  what is highest lead time
df['Actual shipping days'].max()
# Out:
# 6

# %%
#  how many time  the  highest lead time (6 days) appear
df['Actual shipping days'].value_counts().sort_values()
# Out:
# 1     4657
# 0     5080
# 5    28163
# 4    28513
# 6    28723
# 3    28765
# 2    56618
# Name: Actual shipping days, dtype: int64

# %%
#  visualize the  actual lead time
#most frequent actual lead time
df['Actual shipping days'].value_counts().sort_values(ascending=False).plot(kind='bar', rot=0, xlabel='Actual shipping days' , ylabel='Count')
# Out:
# <AxesSubplot:xlabel='Actual shipping days', ylabel='Count'>

# %%
#  maximum estimated lead time
df['Estimated shipping days'].max()
# Out:
# 4

# %%
#  visualize estimated lead time
#most frequent estimated lead time
df['Estimated shipping days'].value_counts().sort_values(ascending= False).plot(kind='bar', rot=0)
# Out:
# <AxesSubplot:>

# %%
df_international.Category.value_counts().sort_values(ascending=False)
# Out:
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport           10984
# Electronics              3156
# Accessories              1780
# Golf Balls               1475
# Girls' Apparel           1201
# Golf Gloves              1070
# Trade-In                  974
# Video Games               838
# Children's Clothing       652
# Women's Clothing          650
# Baseball & Softball       632
# Hockey                    614
# Cameras                   592
# Toys                      529
# Golf Shoes                524
# Pet Supplies              492
# Crafts                    484
# Garden                    484
# DVDs                      483
# Computers                 442
# Golf Apparel              441
# Hunting & Shooting        440
# Music                     434
# ...

# %%
# visualize the most frequent categories
fig, ax= plt.subplots(figsize=(12,12))
df_international.Category.value_counts().sort_values(ascending=False).plot(kind='bar', rot=90,ylabel='count')
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# The most frequent category is following
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport

# %%
# is there any the corelations between columns
corelations= df_international.corr()
fig, ax= plt.subplots(figsize=(12,12))
sns.heatmap(corelations, annot= True, cmap="crest", linewidth= 0.5)
plt.show()

# %%
#Customizing heatmap for better reading
corelations= df_international.corr()
fig, ax= plt.subplots(figsize=(12,12))

# creating a mask by using triangle upper function from numpy
mask= np.triu(np.ones_like(corelations, dtype=bool))
sns.heatmap(corelations, annot= True, cmap="crest", linewidth= 0.5, mask=mask)
plt.show()

# %% [markdown]
# Quantity:  Number of products per order
#
# Order Item Total :  Total amount per order
#
# Order Item Product Price   :  Price of products without discount
#
# Order Item Total  :  Total amount per order
#
# I will expain what is pearsong corelation here in my main thesis
# the corelation is only show for numeric colums only. here we see a strong co relation between  "Order Item Product Price" 'Sales' and is 0.79 cause the more order the item the more the total  product  price ."Order Item Product Price" and 'Order Item total' also have a strong corelations. "Order Item Product Price" and ' Product Price' also  have corerlation is 1 .
# 'sales' and ' order item total ' also have  correaltion of 0.99.

# %%
sns.scatterplot(x="Product Price", y="Order Item Total", data= df_international, hue='Quantity')
# low price  itmes  have more order quantitty
# Out:
# <AxesSubplot:xlabel='Product Price', ylabel='Order Item Total'>

# %%
#fig, ax= plt.subplots(figsize=(12,12))

sns.catplot(x="Order Region",y="Sales", data=df_international, kind="bar")
plt.xticks(rotation=90)
plt.show()
# almost same for all region ecept Western, northen and southern Europe,

# %%
#fig, ax= plt.subplots(figsize=(20,20))
sns.catplot(x="Sales", y="Customer Segment", data=df_international,kind="box")
plt.show()
#some outliner presents. but these are some of the costly items

# %%
#fig, ax= plt.subplots(figsize=(20,20))
sns.catplot(x="Customer Segment", y="Sales", data=df_international,kind="box")
plt.show()
#some outliner presents  but these are some of the costly items

# %%
print('max',df_international['Sales'].max())
print('min', df_international['Sales'].min())
print('median', df_international['Sales'].median()
     )
print('mode', df_international['Sales'].mode().iat[0])
# Out:
# max 1999.98999
# min 9.989999771
# median 199.9199982
# mode 129.9900055

# %% [markdown]
# ###  Outlier
# it is clearly show that there are some product which has higher values , i can say it is outlier but does it effect our model or not if it is effetct our moodle performance then I will see how many are they and repalce it with  mdeian or mode. later

# %%
df_international['Sales'].mode().iat[0]
# Out:
# 129.9900055

# %%
df_international['Sales'].mode()
# Out:
# 0    129.990005
# dtype: float64

# %%
fig, ax= plt.subplots(figsize=(20,20))
ax=sns.countplot(x="Category",data=df_international, hue="Customer Segment")
plt.xticks(rotation=90)
plt.show()

# %%
# people prefer standard shipping
# single quantity also preffer  1st and 2nd class shipping
# IF it single product people take also same days shipping 
fig, ax= plt.subplots(figsize=(10,10))
ax=sns.countplot(x="Quantity",data=df_international, hue="Shipping Mode")
plt.show()

# %% [markdown]
# in overall , 'consumer' customer category is the height. the frequent sales categories is
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport

# %%
# Multiple observations per x-value
sns.relplot(x="Actual shipping days", y="Sales",  data=df_international, kind="line")

# %%
sns.histplot(df_international['Quantity'], stat="density", kde=True, label="100% Equities", linewidth=0)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Density'>

# %%
#sns.swarmplot(data=df_international, y="Late_risk", x="Order Region")

# %%
#sns.swarmplot(x="Order Region" , y="Sales", data= df_international)

# %%
sns.stripplot(x="Order Region" , y="Sales", data= df_international,alpha=0.5,size=3)
plt.xticks(rotation=90)

plt.savefig('stripplot.png')
# also have to make an explanation how to expain  this kind of plot.

# %%
sns.pairplot(df_international)
# have to make an explanation

# %% [markdown]
#  # Is There any differece between estimated and actual lead time  i HAVE TO CHECK

# %%
df_international["Customer Segment"].value_counts()
# Out:
# Consumer       93504
# Corporate      54789
# Home Office    32226
# Name: Customer Segment, dtype: int64

# %%
# is there any relation betweem this two variable 
sns.catplot(x="Customer Segment", y= "Quantity", data=df_international,kind='bar' )
plt.xticks(rotation=90)
plt.show()

# %%
# have to find some explanation , pf this point plot.
sns.catplot(x="Customer Segment", y= "Quantity", data=df_international,kind='point', hue='Late_risk' )
plt.xticks(rotation=90)
plt.show()

# %%
#Southeast_Asia= df_international['Estimated shipping days'] =='Southeast Asia'
#fig, ax = plt.subplots()

#ax.bar(df_international['Order Region'], df_international['Actual shipping days'])
#plt.xticks(rotation=90)
#plt.show()

# %%
# Where they most ship their products

sns.countplot(x="Order Region", data=df_international )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ####  have to find Where they most ship their products what is  maximum delivery time there

# %% [markdown]
#  #### " Orders Date " and  " Shipping date " er unique values dekheo ,may be some values are missing

# %%
### "Shipping mode" er sathe "late delivery risk" and "actual shipping date er relational grap korbo"

# %% [markdown]
# # Split dataframe according to Numeric and Non-Numeric data types

# %% [markdown]
# ### Numeric DataFrame

# %%
# Select specific data type (integer and float)
only_int= df_international.select_dtypes(include=['int64', 'float64'])
print(only_int.head())
# Out:
#    Actual shipping days  Estimated shipping days  Late_risk  \
# 0                     3                        4          0
# 1                     5                        4          1
# 2                     4                        4          0
# 3                     3                        4          0
# 4                     2                        4          0
#
#    Order Item Product Price  Quantity   Sales  Order Item Total  Product Price
# 0                    327.75         1  327.75        314.640015         327.75
# 1                    327.75         1  327.75        311.359985         327.75
# 2                    327.75         1  327.75        309.720001         327.75
# 3                    327.75         1  327.75        304.809998         327.75
# 4                    327.75         1  327.75        298.250000         327.75

# %%
only_int.shape
# Out:
# (180519, 8)

# %%
print(only_int.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Actual shipping days      180519 non-null  int64
#  1   Estimated shipping days   180519 non-null  int64
#  2   Late_risk                 180519 non-null  int64
#  3   Order Item Product Price  180519 non-null  float64
#  4   Quantity                  180519 non-null  int64
#  5   Sales                     180519 non-null  float64
#  6   Order Item Total          180519 non-null  float64
#  7   Product Price             180519 non-null  float64
# dtypes: float64(4), int64(4)
# memory usage: 11.0 MB
# None

# %%
# The describe method for numeric columns

print(only_int.describe())
# Out:
#        Actual shipping days  Estimated shipping days      Late_risk  \
# count         180519.000000            180519.000000  180519.000000
# mean               3.497654                 2.931847       0.548291
# std                1.623722                 1.374449       0.497664
# min                0.000000                 0.000000       0.000000
# 25%                2.000000                 2.000000       0.000000
# 50%                3.000000                 4.000000       1.000000
# 75%                5.000000                 4.000000       1.000000
# max                6.000000                 4.000000       1.000000
#
#        Order Item Product Price       Quantity          Sales  \
# count             180519.000000  180519.000000  180519.000000
# mean                 141.232550       2.127638     203.772096
# std                  139.732492       1.453451     132.273077
# min                    9.990000       1.000000       9.990000
# ...

# %% [markdown]
# ### Non-Numeric DataFrame

# %%
# Select specific data type (object)
only_obj= df_international.select_dtypes(include=['object'])
print(only_obj.head())
# Out:
#     Delivery Status        Category  Order City    Order Region  \
# 0  Advance shipping  Sporting Goods      Bekasi  Southeast Asia
# 1     Late delivery  Sporting Goods     Bikaner      South Asia
# 2  Shipping on time  Sporting Goods     Bikaner      South Asia
# 3  Advance shipping  Sporting Goods  Townsville         Oceania
# 4  Advance shipping  Sporting Goods  Townsville         Oceania
#
#        Order State Customer Segment Department      Orders Date  \
# 0  Java Occidental         Consumer    Fitness  1/31/2018 22:56
# 1         Rajastán         Consumer    Fitness  1/13/2018 12:27
# 2         Rajastán         Consumer    Fitness  1/13/2018 12:06
# 3       Queensland      Home Office    Fitness  1/13/2018 11:45
# 4       Queensland        Corporate    Fitness  1/13/2018 11:24
#
#       Order Status  Product Name    Shipping date   Shipping Mode
# 0         COMPLETE  Smart watch    02-03-18 22:56  Standard Class
# ...

# %%
only_obj.shape
# Out:
# (180519, 12)

# %%
only_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Delivery Status   180519 non-null  object
#  1   Category          180519 non-null  object
#  2   Order City        180519 non-null  object
#  3   Order Region      180519 non-null  object
#  4   Order State       180519 non-null  object
#  5   Customer Segment  180519 non-null  object
#  6   Department        180519 non-null  object
#  7   Orders Date       180519 non-null  object
#  8   Order Status      180519 non-null  object
#  9   Product Name      180519 non-null  object
#  10  Shipping date     180519 non-null  object
#  11  Shipping Mode     180519 non-null  object
# dtypes: object(12)
# memory usage: 16.5+ MB

# %%
# The describe method for non-numeric columns
only_obj.describe(exclude='number')
# Out:
#        Delivery Status Category     Order City     Order Region Order State  \
# count           180519   180519         180519           180519      180519
# unique               4       50           3597               23        1089
# top      Late delivery   Cleats  Santo Domingo  Central America  Inglaterra
# freq             98977    24551           2211            28341        6722
#
#        Customer Segment Department     Orders Date Order Status  \
# count            180519     180519          180519       180519
# unique                3         11           65752            9
# top            Consumer   Fan Shop  04-11-16 10:12     COMPLETE
# freq              93504      66861               5        59491
#
#                             Product Name  Shipping date   Shipping Mode
# count                             180519         180519          180519
# unique                               118          63701               4
# ...

# %%
only_obj['Category'].unique()
# Out:
# array(['Sporting Goods', 'Cleats', 'Shop By Sport', "Women's Apparel",
#        'Electronics', 'Boxing & MMA', 'Cardio Equipment', 'Trade-In',
#        "Kids' Golf Clubs", 'Hunting & Shooting', 'Baseball & Softball',
#        "Men's Footwear", 'Camping & Hiking', 'Consumer Electronics',
#        'Cameras ', 'Computers', 'Basketball', 'Soccer', "Girls' Apparel",
#        'Accessories', "Women's Clothing", 'Crafts', "Men's Clothing",
#        'Tennis & Racquet', 'Fitness Accessories', 'As Seen on  TV!',
#        'Golf Balls', 'Strength Training', "Children's Clothing",
#        'Lacrosse', 'Baby ', 'Fishing', 'Books ', 'DVDs', 'CDs ', 'Garden',
#        'Hockey', 'Pet Supplies', 'Health and Beauty', 'Music',
#        'Video Games', 'Golf Gloves', 'Golf Bags & Carts', 'Golf Shoes',
#        'Golf Apparel', "Women's Golf Clubs", "Men's Golf Clubs", 'Toys',
#        'Water Sports', 'Indoor/Outdoor Games'], dtype=object)

# %% [markdown]
# # Cleaning  DataFrame(Missing Values)

# %% [markdown]
# ###  have to Find Duplicates values

# %%
# Finding missing values 
only_int.isna().sum()
# Out:
# Actual shipping days        0
# Estimated shipping days     0
# Late_risk                   0
# Order Item Product Price    0
# Quantity                    0
# Sales                       0
# Order Item Total            0
# Product Price               0
# dtype: int64

# %%
print(only_int.isnull().sum())
# Out:
# Actual shipping days        0
# Estimated shipping days     0
# Late_risk                   0
# Order Item Product Price    0
# Quantity                    0
# Sales                       0
# Order Item Total            0
# Product Price               0
# dtype: int64

# %%
# Finding missing values
only_obj.isna().sum()
# Out:
# Delivery Status     0
# Category            0
# Order City          0
# Order Region        0
# Order State         0
# Customer Segment    0
# Department          0
# Orders Date         0
# Order Status        0
# Product Name        0
# Shipping date       0
# Shipping Mode       0
# dtype: int64

# %%
print(only_obj.isnull().sum())
# Out:
# Delivery Status     0
# Category            0
# Order City          0
# Order Region        0
# Order State         0
# Customer Segment    0
# Department          0
# Orders Date         0
# Order Status        0
# Product Name        0
# Shipping date       0
# Shipping Mode       0
# dtype: int64

# %%
# Import  missingno and pyplot library
import missingno as msno
import matplotlib.pyplot as plt

# %%
# Numeric
msno.matrix(only_int)
plt.show()

# %%
# Non-numeric
msno.matrix(only_int)
plt.show()

# %% [markdown]
#  Luckly we do not have any missing value, but I will check further.

# %% [markdown]
# # Feature Engineering and selection

# %% [markdown]
# ### Date Time columns
# Is ML model works with  Date Time ? I have to find it

# %% [markdown]
#  "Orders Date" and "Shipping date" columnns are not date type so we need to convert it

# %%
# Convert to date
only_obj['Orders Date_datetype'] = pd.to_datetime(only_obj['Orders Date'])
# Out:
# <ipython-input-236-7c64226e1827>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_obj['Orders Date_datetype'] = pd.to_datetime(only_obj['Orders Date'])

# %%
# Convert to date
only_obj['Shipping date_datetype'] = pd.to_datetime(only_obj['Shipping date'])
# Out:
# <ipython-input-237-3d000d7c8fa3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_obj['Shipping date_datetype'] = pd.to_datetime(only_obj['Shipping date'])

# %%
only_obj.dtypes
# Out:
# Delivery Status                   object
# Category                          object
# Order City                        object
# Order Region                      object
# Order State                       object
# Customer Segment                  object
# Department                        object
# Orders Date                       object
# Order Status                      object
# Product Name                      object
# Shipping date                     object
# Shipping Mode                     object
# Orders Date_datetype      datetime64[ns]
# Shipping date_datetype    datetime64[ns]
# dtype: object

# %% [markdown]
# #  Dealing with Categorical Data

# %%
only_obj.dtypes
# Out:
# Delivery Status                   object
# Category                          object
# Order City                        object
# Order Region                      object
# Order State                       object
# Customer Segment                  object
# Department                        object
# Orders Date                       object
# Order Status                      object
# Product Name                      object
# Shipping date                     object
# Shipping Mode                     object
# Orders Date_datetype      datetime64[ns]
# Shipping date_datetype    datetime64[ns]
# dtype: object

# %%
# The describe method for non-numeric columns
only_obj.describe(exclude='number')
# Out:
# <ipython-input-240-abb0f842ae5c>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   only_obj.describe(exclude='number')
# <ipython-input-240-abb0f842ae5c>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   only_obj.describe(exclude='number')
#        Delivery Status Category     Order City     Order Region Order State  \
# count           180519   180519         180519           180519      180519
# unique               4       50           3597               23        1089
# top      Late delivery   Cleats  Santo Domingo  Central America  Inglaterra
# ...

# %% [markdown]
# ### Whave to check do I need Feature Scalling, as I use Random Forest and XGboost I do not need it

# %% [markdown]
# Customer segment:  categorical
# categorical : count frequency
# Delivery Status : Custom Binary Encoding/ not Categorical, use pandas qcut()
# Order City: Drop
#
# Order State: drop
# Department: categorical
# Order staturs : categorical
# Product Name: drop while doing Lead time prediction .

# %% [markdown]
# # Approach  - Label Encoding on "Customer Segment columns"

# %%
# Get value counts on DataFrame
only_obj.groupby('Customer Segment').count()
# Out:
#                   Delivery Status  Category  Order City  Order Region  \
# Customer Segment
# Consumer                    93504     93504       93504         93504
# Corporate                   54789     54789       54789         54789
# Home Office                 32226     32226       32226         32226
#
#                   Order State  Department  Orders Date  Order Status  \
# Customer Segment
# Consumer                93504       93504        93504         93504
# Corporate               54789       54789        54789         54789
# Home Office             32226       32226        32226         32226
#
#                   Product Name  Shipping date  Shipping Mode  \
# Customer Segment
# Consumer                 93504          93504          93504
# Corporate                54789          54789          54789
# Home Office              32226          32226          32226
#
#                   Orders Date_datetype  Shipping date_datetype
# Customer Segment
# ...

# %%
only_obj['Customer Segment'].value_counts()
# Out:
# Consumer       93504
# Corporate      54789
# Home Office    32226
# Name: Customer Segment, dtype: int64

# %%
only_obj['Customer Segment'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Taking help for  making Label encoding
# https://pbpython.com/categorical-encoding.html
#
# https://stackoverflow.com/questions/51102205/how-to-know-the-labels-assigned-by-astypecategory-cat-codes

# %%
#Approach #2 - Label Encoding
# One trick you can use in pandas is to convert a column to a category, then use those category values for your label encoding:
# Then you can assign the encoded variable to a new column using the cat.codes accessor:
#I categorized each of my variables into numbers by using
#  casting to category data.

only_obj["Customer Segment"] = only_obj["Customer Segment"].astype('category')


# assign the encoded variable to a new column using the cat.codes accessor:
# to access ".cat" w have to convert the column intio 'categorical' datatype
only_obj['Customer Segment cat']=only_obj['Customer Segment'].cat.codes

print(only_obj.head())

print('\n','Unique values' ,only_obj['Customer Segment cat'].unique())
# Out:
#     Delivery Status        Category  Order City    Order Region  \
# 0  Advance shipping  Sporting Goods      Bekasi  Southeast Asia
# 1     Late delivery  Sporting Goods     Bikaner      South Asia
# 2  Shipping on time  Sporting Goods     Bikaner      South Asia
# 3  Advance shipping  Sporting Goods  Townsville         Oceania
# 4  Advance shipping  Sporting Goods  Townsville         Oceania
#
#        Order State Customer Segment Department      Orders Date  \
# 0  Java Occidental         Consumer    Fitness  1/31/2018 22:56
# 1         Rajastán         Consumer    Fitness  1/13/2018 12:27
# 2         Rajastán         Consumer    Fitness  1/13/2018 12:06
# 3       Queensland      Home Office    Fitness  1/13/2018 11:45
# 4       Queensland        Corporate    Fitness  1/13/2018 11:24
#
#       Order Status  Product Name    Shipping date   Shipping Mode  \
# 0         COMPLETE  Smart watch    02-03-18 22:56  Standard Class
# ...

# %% [markdown]
# the upper error said to covert  'Customer Segment' column into 'categorical' use the folowing code
#
# df.loc[:,"Customer Segment"] = 'category'

# %%
# After label encoding , what is our cat code.
only_obj['Customer Segment cat'].unique()
# Out:
# array([0, 2, 1], dtype=int8)

# %%
#How to know the labels assigned by astype('category').cat.codes?


print(only_obj['Customer Segment'].cat.categories[0])
print(only_obj['Customer Segment'].cat.categories[1])
print(only_obj['Customer Segment'].cat.categories[2])
# Out:
# Consumer
# Corporate
# Home Office

# %% [markdown]
# # Approach  - Count/Frequency Encoding on "Category"  and ' Order Region ' column
#
# https://www.youtube.com/watch?v=o4UDAFd0DgY
#
#
# https://www.youtube.com/watch?v=MPnNC6kkNC4

# %%
# Let's obtain the counts of each of the labels in variavle'Category'

only_obj['Category'].value_counts(sort=True)
# Out:
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport           10984
# Electronics              3156
# Accessories              1780
# Golf Balls               1475
# Girls' Apparel           1201
# Golf Gloves              1070
# Trade-In                  974
# Video Games               838
# Children's Clothing       652
# Women's Clothing          650
# Baseball & Softball       632
# Hockey                    614
# Cameras                   592
# Toys                      529
# Golf Shoes                524
# Pet Supplies              492
# Crafts                    484
# Garden                    484
# DVDs                      483
# Computers                 442
# Golf Apparel              441
# Hunting & Shooting        440
# Music                     434
# ...

# %%
only_obj['Category'].unique()
# Out:
# array(['Sporting Goods', 'Cleats', 'Shop By Sport', "Women's Apparel",
#        'Electronics', 'Boxing & MMA', 'Cardio Equipment', 'Trade-In',
#        "Kids' Golf Clubs", 'Hunting & Shooting', 'Baseball & Softball',
#        "Men's Footwear", 'Camping & Hiking', 'Consumer Electronics',
#        'Cameras ', 'Computers', 'Basketball', 'Soccer', "Girls' Apparel",
#        'Accessories', "Women's Clothing", 'Crafts', "Men's Clothing",
#        'Tennis & Racquet', 'Fitness Accessories', 'As Seen on  TV!',
#        'Golf Balls', 'Strength Training', "Children's Clothing",
#        'Lacrosse', 'Baby ', 'Fishing', 'Books ', 'DVDs', 'CDs ', 'Garden',
#        'Hockey', 'Pet Supplies', 'Health and Beauty', 'Music',
#        'Video Games', 'Golf Gloves', 'Golf Bags & Carts', 'Golf Shoes',
#        'Golf Apparel', "Women's Golf Clubs", "Men's Golf Clubs", 'Toys',
#        'Water Sports', 'Indoor/Outdoor Games'], dtype=object)

# %%
#only_obj['Category'].unique()

# %% [markdown]
# If some labels has same count, then they will replaced with the same count and that will loose some of infomation so I check is the
# any of labels has same count or not

# %%
# is the any of labels has same count or not
from collections import Counter
A=only_obj['Category'].value_counts(sort=True).unique()


print(type(A))

Counter(A)
# Out:
# <class 'numpy.ndarray'>
# Counter({24551: 1,
#          22246: 1,
#          21035: 1,
#          19298: 1,
#          17325: 1,
#          15540: 1,
#          13729: 1,
#          12487: 1,
#          10984: 1,
#          3156: 1,
#          1780: 1,
#          1475: 1,
#          1201: 1,
#          1070: 1,
#          974: 1,
#          838: 1,
#          652: 1,
#          650: 1,
#          632: 1,
#          614: 1,
#          592: 1,
#          529: 1,
#          524: 1,
#          492: 1,
#          484: 1,
#          483: 1,
#          442: 1,
#          441: 1,
#          440: 1,
#          434: 1,
#          431: 1,
#          423: 1,
#          405: 1,
#          384: 1,
#          362: 1,
#          357: 1,
#          343: 1,
#          328: 1,
#          309: 1,
#          283: 1,
#          271: 1,
#          208: 1,
#          207: 1,
#          181: 1,
#          138: 1,
#          111: 1,
#          68: 1,
#          67: 1,
#          61: 1})

# %% [markdown]
# As all label has unique counts so we can use count frequency approach

# %%
# convert to dict, that is help for mapping later on.
# that will capture  in a dictonary  that we  can use to re-mapthe label

frequency_map= only_obj['Category'].value_counts().to_dict()
print(frequency_map)
# Out:
# {'Cleats': 24551, "Men's Footwear": 22246, "Women's Apparel": 21035, 'Indoor/Outdoor Games': 19298, 'Fishing': 17325, 'Water Sports': 15540, 'Camping & Hiking': 13729, 'Cardio Equipment': 12487, 'Shop By Sport': 10984, 'Electronics': 3156, 'Accessories': 1780, 'Golf Balls': 1475, "Girls' Apparel": 1201, 'Golf Gloves': 1070, 'Trade-In': 974, 'Video Games': 838, "Children's Clothing": 652, "Women's Clothing": 650, 'Baseball & Softball': 632, 'Hockey': 614, 'Cameras ': 592, 'Toys': 529, 'Golf Shoes': 524, 'Pet Supplies': 492, 'Crafts': 484, 'Garden': 484, 'DVDs': 483, 'Computers': 442, 'Golf Apparel': 441, 'Hunting & Shooting': 440, 'Music': 434, 'Consumer Electronics': 431, 'Boxing & MMA': 423, 'Books ': 405, "Kids' Golf Clubs": 384, 'Health and Beauty': 362, 'Sporting Goods': 357, 'Lacrosse': 343, 'Tennis & Racquet': 328, 'Fitness Accessories': 309, "Men's Golf Clubs": 283, 'CDs ': 271, "Men's Clothing": 208, 'Baby ': 207, "Women's Golf Clubs": 181, 'Soccer': 138, 'Strength Training':
# ...

# %%
only_obj['Category_map']= only_obj['Category'].map(frequency_map)
# this code somple map for example 'Cleats' label into it's cint wich is '24551'
# Out:
# <ipython-input-252-20c1dd897729>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_obj['Category_map']= only_obj['Category'].map(frequency_map)

# %% [markdown]
# Sporting Goods            357
# sanity check

# %%
only_obj['Category']
# Out:
# 0         Sporting Goods
# 1         Sporting Goods
# 2         Sporting Goods
# 3         Sporting Goods
# 4         Sporting Goods
#                ...
# 180514           Fishing
# 180515           Fishing
# 180516           Fishing
# 180517           Fishing
# 180518           Fishing
# Name: Category, Length: 180519, dtype: object

# %%
only_obj['Category_map']
# Out:
# 0           357
# 1           357
# 2           357
# 3           357
# 4           357
#           ...
# 180514    17325
# 180515    17325
# 180516    17325
# 180517    17325
# 180518    17325
# Name: Category_map, Length: 180519, dtype: int64

# %% [markdown]
# # Order Region

# %%
# Let's obtain the counts of each of the labels in variavle'Category'

only_obj['Order Region'].value_counts(sort=True)
# Out:
# Central America    28341
# Western Europe     27109
# South America      14935
# Oceania            10148
# Northern Europe     9792
# Southeast Asia      9539
# Southern Europe     9431
# Caribbean           8318
# West of USA         7993
# South Asia          7731
# Eastern Asia        7280
# East of USA         6915
# West Asia           6009
# US Center           5887
# South of  USA       4045
# Eastern Europe      3920
# West Africa         3696
# North Africa        3232
# East Africa         1852
# Central Africa      1677
# Southern Africa     1157
# Canada               959
# Central Asia         553
# Name: Order Region, dtype: int64

# %%
only_obj['Order Region'].unique()
# Out:
# array(['Southeast Asia', 'South Asia', 'Oceania', 'Eastern Asia',
#        'West Asia', 'West of USA ', 'US Center ', 'West Africa',
#        'Central Africa', 'North Africa', 'Western Europe',
#        'Northern Europe', 'Central America', 'Caribbean', 'South America',
#        'East Africa', 'Southern Europe', 'East of USA', 'Canada',
#        'Southern Africa', 'Central Asia', 'Eastern Europe',
#        'South of  USA '], dtype=object)

# %%
# is the any of labels has same count or not
from collections import Counter
B=only_obj['Order Region'].value_counts(sort=True).unique()


print(type(B))

Counter(B)
# Out:
# <class 'numpy.ndarray'>
# Counter({28341: 1,
#          27109: 1,
#          14935: 1,
#          10148: 1,
#          9792: 1,
#          9539: 1,
#          9431: 1,
#          8318: 1,
#          7993: 1,
#          7731: 1,
#          7280: 1,
#          6915: 1,
#          6009: 1,
#          5887: 1,
#          4045: 1,
#          3920: 1,
#          3696: 1,
#          3232: 1,
#          1852: 1,
#          1677: 1,
#          1157: 1,
#          959: 1,
#          553: 1})

# %%
# convert to dict, that is help for mapping later on.
# that will capture  in a dictonary  that we  can use to re-mapthe label

frequency_map1= only_obj['Order Region'].value_counts().to_dict()
print(frequency_map1)
# Out:
# {'Central America': 28341, 'Western Europe': 27109, 'South America': 14935, 'Oceania': 10148, 'Northern Europe': 9792, 'Southeast Asia': 9539, 'Southern Europe': 9431, 'Caribbean': 8318, 'West of USA ': 7993, 'South Asia': 7731, 'Eastern Asia': 7280, 'East of USA': 6915, 'West Asia': 6009, 'US Center ': 5887, 'South of  USA ': 4045, 'Eastern Europe': 3920, 'West Africa': 3696, 'North Africa': 3232, 'East Africa': 1852, 'Central Africa': 1677, 'Southern Africa': 1157, 'Canada': 959, 'Central Asia': 553}

# %%
only_obj['Order Region_map']= only_obj['Order Region'].map(frequency_map1)
# this code somple map for example 'Cleats' label into it's cint wich is '24551'
# Out:
# <ipython-input-259-33a7fadf2e53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_obj['Order Region_map']= only_obj['Order Region'].map(frequency_map1)

# %% [markdown]
# # Approch - Custom Binary Encoding of " Delivery Status"
#
# In this particular data set, there is a column called 'Delivery Status ' that contains several different values.
# For the sake of discussion, maybe all we care about is whether or not the Delivery was sucessful  or not.
#
# If this is the case, then we could use the 'str'  accessor plus ' np.where ' to create a new column the indicates whether or not the Delivery  has sucessful or not .

# %%
# Let's have a look how manuy diffeent lavels are there 

only_obj['Delivery Status'].unique()
# Out:
# array(['Advance shipping', 'Late delivery', 'Shipping on time',
#        'Shipping canceled'], dtype=object)

# %%
# see how many times of each lable  appears

only_obj['Delivery Status']. value_counts()

# can  you there is 'Shipping canceled     7754' has bees cancel.
# Out:
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: Delivery Status, dtype: int64

# %% [markdown]
# I find that this is a handy function I use quite a bit but sometimes forget the syntax so here is a graphic showing what we are doing:
# ![image-2.png](attachment:image-2.png)
#
#
# link : https://pbpython.com/categorical-encoding.html

# %%
# Binariza the colum
only_obj["Delivery Status_code"] = np.where(only_obj['Delivery Status'].str.contains(pat="canceled"), 0, 1)
# Out:
# <ipython-input-262-3d656c035c0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_obj["Delivery Status_code"] = np.where(only_obj['Delivery Status'].str.contains(pat="canceled"), 0, 1)

# %%
# Cheching is that worksor not 
only_obj['Delivery Status'].head(20)
# Out:
# 0      Advance shipping
# 1         Late delivery
# 2      Shipping on time
# 3      Advance shipping
# 4      Advance shipping
# 5     Shipping canceled
# 6         Late delivery
# 7         Late delivery
# 8         Late delivery
# 9         Late delivery
# 10    Shipping canceled
# 11        Late delivery
# 12        Late delivery
# 13        Late delivery
# 14        Late delivery
# 15        Late delivery
# 16        Late delivery
# 17        Late delivery
# 18        Late delivery
# 19     Shipping on time
# Name: Delivery Status, dtype: object

# %%
# Cheching is that worksor not
only_obj["Delivery Status_code"].head(20)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    1
# 18    1
# 19    1
# Name: Delivery Status_code, dtype: int32

# %% [markdown]
# # Order Status

# %%
# Let's have a look how manuy diffeent lavels are there 

only_obj['Order Status'].unique()
# Out:
# array(['COMPLETE', 'PENDING', 'CLOSED', 'PENDING_PAYMENT', 'CANCELED',
#        'PROCESSING', 'SUSPECTED_FRAUD', 'ON_HOLD', 'PAYMENT_REVIEW'],
#       dtype=object)

# %%
only_obj['Order Status'].value_counts(normalize=True)
# Out:
# COMPLETE           0.329555
# PENDING_PAYMENT    0.220653
# PROCESSING         0.121328
# PENDING            0.112049
# CLOSED             0.108664
# ON_HOLD            0.054310
# SUSPECTED_FRAUD    0.022502
# CANCELED           0.020452
# PAYMENT_REVIEW     0.010486
# Name: Order Status, dtype: float64

# %% [markdown]
#  so 10th row  has value ' Delivery  Status '  Cancel so it is maped as  '0'

# %% [markdown]
# # Approach One Hot Encoding
# Department: categorical
# Order staturs : categorical

# %% [markdown]
# One-Hot Encoder
# Though label encoding is straight but it has the disadvantage that the numeric values can be misinterpreted by algorithms as having some sort of hierarchy/order in them. This ordering issue is addressed in another common alternative approach called ‘One-Hot Encoding’. In this strategy, each category value is converted into a new column and assigned a 1 or 0 (notation for true/false) value to the column. Let’s consider the previous example of bridge type and safety levels with one-hot encoding.
#
# https://towardsdatascience.com/categorical-encoding-using-label-encoding-and-one-hot-encoder-911ef77fb5bd
#
# https://www.analyticsvidhya.com/blog/2020/03/one-hot-encoding-vs-label-encoding-using-scikit-learn/
#
# SciKit Learn Pipe line
# https://www.youtube.com/watch?v=irHhDMbw3xo

# %%
only_obj['Department'].value_counts(normalize= True)
# Out:
# Fan Shop              0.370382
# Apparel               0.271428
# Golf                  0.184025
# Footwear              0.080462
# Outdoors              0.053656
# Fitness               0.013733
# Discs Shop            0.011223
# Technology            0.008115
# Pet Shop              0.002725
# Book Shop             0.002244
# Health and Beauty     0.002005
# Name: Department, dtype: float64

# %% [markdown]
# # from sklearn.preprocessing import OneHotEncoder
#
#  This will do wile we will do Model

# %%
only_obj['Order Status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: Order Status, dtype: int64

# %% [markdown]
# # Approach One Hot Encoding Shipping Mode
#
# Is it Possible to do multi columns One Hot encoding

# %%
only_obj['Shipping Mode'].value_counts()
# Out:
# Standard Class    107752
# Second Class       35216
# First Class        27814
# Same Day            9737
# Name: Shipping Mode, dtype: int64

# %% [markdown]
# # Approach Drop
#
#
# Order City: Drop
#
# Order State: drop
#
# Product Name: drop while doing Lead time prediction.
#
# and we also drop the columns on that we apply feature  engineering

# %%
# We drop here 10 columns here.
obj_df = only_obj.drop(['Order City', 'Order State', 'Product Name',"Orders Date" , "Shipping date",'Customer Segment','Category','Delivery Status','Order Region','Order Status'], axis=1)

# %%
# dimension of dataset
only_obj.shape
# Out:
# (180519, 18)

# %%
# dimension of dataset
obj_df.shape
# Out:
# (180519, 8)

# %%
# How many columns now we have
18-10
# Out:
# 8

# %% [markdown]
# # Joining

# %% [markdown]
# Now we join our integer and obejct  dataset

# %%
obj_df.dtypes
# Out:
# Department                        object
# Shipping Mode                     object
# Orders Date_datetype      datetime64[ns]
# Shipping date_datetype    datetime64[ns]
# Customer Segment cat                int8
# Category_map                       int64
# Order Region_map                   int64
# Delivery Status_code               int32
# dtype: object

# %%
df_lt= pd.concat([only_int, obj_df], axis=1)

# %%
# Check all have same columns or not , cause it is important that all must have same columns 
print(only_int.shape)
print(obj_df.shape)

print(df_lt.shape)
# Out:
# (180519, 8)
# (180519, 8)
# (180519, 16)

# %% [markdown]
# # Saving DataFrame

# %%
df_lt.to_csv(r'E:\Hochschule Ansbach\Thesis\DATA\df_LeadTime.csv' ,  index = False ) 
             #  index = False  this is avoid the Unnamed column
